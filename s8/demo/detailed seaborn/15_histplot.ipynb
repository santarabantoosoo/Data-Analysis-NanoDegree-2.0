# %% [markdown]
# # Seaborn: histplot

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.11.1'

# %%
penguins = sns.load_dataset('penguins')

# %%
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.histplot(data = penguins, x = 'flipper_length_mm', hue = 'species');

# %%
sns.displot(data = penguins, x = 'flipper_length_mm', kind = 'kde', row = 'species', col = 'sex');

# %%
sns.(data = penguins, x = 'flipper_length_mm', kind = 'kde', row = 'species', col = 'sex');

# %%
sns.barplot(data = penguins, x = 'species', y = 'flipper_length_mm', estimator = np.sum, ci = None);

# %%
sns.boxplot(data = penguins, x = 'species', y = 'flipper_length_mm');

# %%
sns.violinplot(data = penguins, x = 'species', y = 'flipper_length_mm');

# %%
m = sns.displot(data = penguins, kind = 'kde', x = 'flipper_length_mm');

# %%
type(m)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
sns.histplot(data = penguins, x = 'flipper_length_mm');

# %%
sns.histplot(data = penguins, x = 'flipper_length_mm', bins = 5);

# %%
sns.histplot(data = penguins, x = 'body_mass_g', kde = True);

# %%
sns.displot(data = penguins, x = 'flipper_length_mm', row = 'species');

# %%
sns.scatterplot(data = penguins, x = 'bill_depth_mm', y = 'flipper_length_mm');

# %%
sns.scatterplot(data = penguins, x = 'species', y = 'flipper_length_mm');

# %%
sns.catplot(data = penguins, x = 'island', y = 'flipper_length_mm', row = 'species', col = 'sex', kind = 'box');

# %%
sns.swarmplot(data = penguins, x = 'species', y = 'flipper_length_mm');
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 6.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.violinplot(data = penguins, x = 'species', y = 'flipper_length_mm');

# %%
sns.displot(data = penguins, x = 'flipper_length_mm', col = 'species', kind = 'kde');

# %%
sns.histplot(data = penguins, x = 'flipper_length_mm', kde = True);

# %%
sns.histplot(penguins.flipper_length_mm);

# %%
sns.barplot(data = penguins, x = 'flipper_length_mm', y = 'species');

# %%
# penguins.species.value_counts()

sns.countplot(data = penguins, y = 'species');

# %%
sns.histplot()
# Out:
# array(['Torgersen', 'Biscoe', 'Dream'], dtype=object)

# %%
sns.displot(x = 'bill_depth_mm', data = penguins, kind = 'hist', col = 'sex', row = 'species');

# %%
sns.kdeplot(data = penguins, x = "body_mass_g");

# %%
sns.catplot(data = penguins, x = "body_mass_g", y = 'sex', kind = 'box', col = 'species');

# %%
sns.histplot(x = "body_mass_g", data = penguins);

# %%
sns.histplot(x = 'body_mass_g' , data = penguins);

# %%
sns.kdeplot(x = 'body_mass_g' , data = penguins);

# %%
sns.histplot(x = 'body_mass_g' , data = penguins);

# %%
sns.histplot(x = 'flipper_length_mm' , data = penguins);

# %%
sns.boxplot(x = 'flipper_length_mm', y = 'sex' , data = penguins);

# %%
sns.displot(kind = 'kde', data = penguins, x = 'flipper_length_mm', col = 'sex')

# %%
sns.displot(kind = 'kde', data = penguins, x = 'flipper_length_mm', col = 'body_mass_g')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-e9d5ea1c915d> in <module>
# ----> 1 sns.displot(kind = 'kde', data = penguins, x = 'flipper_length_mm', col = 'body_mass_g')
#
# ~\miniconda3\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2180         facet_kws = {}
#    2181
# -> 2182     g = FacetGrid(
#    2183         data=data, row=row_name, col=col_name,
#    2184         col_wrap=col_wrap, row_order=row_order,
#
# ~\miniconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
# ...

# %%
penguins.shape
# Out:
# (344, 7)

# %%
penguins.dropna(inplace=True)

# %%
penguins.shape
# Out:
# (333, 7)

# %% [markdown]
# ## Intro Visuals

# %% [markdown]
# `distplot` has now been deprecated.  Switch to `histplot` for histogram plots.

# %%
sns.distplot(penguins.flipper_length_mm, kde = False);
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
from matplotlib import pyplot as plt

# %%
plt.rc('xtick', labelsize=12)
plt.rc('ytick', labelsize=12)
plt.rc('axes', labelsize=14)

# %%
sns.set_style('white')

# %%
sns.histplot(penguins.flipper_length_mm, bins = 30)
sns.despine(left = True)
plt.xlabel('');
# plt.tight_layout();

# %%
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# %%
plt.figure(figsize=(7,4))
sns.histplot(penguins.flipper_length_mm, alpha=1)
sns.despine(left=True)
plt.yticks([])
plt.xlabel('')
plt.ylabel('')
plt.tight_layout();

# %%
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)
plt.rc('axes', labelsize=10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('darkgrid')

# %%
sns.histplot(penguins.flipper_length_mm, stat = 'probability');

# %%
sns.histplot(y = 'flipper_length_mm', data=penguins);

# %% [markdown]
# ### `kde`

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             kde=True
             );

# %% [markdown]
# ### `bins`

# %%
sns.histplot(x='flipper_length_mm', data=penguins, bins=20, kde = True);

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             bins=[170, 185, 200, 215, 225, 250]
             );

# %% [markdown]
# ### `binwidth` and `binrange`

# %%
sns.histplot(x='flipper_length_mm', data=penguins, 
             binwidth=10, binrange=(170, 230)
            );

# %% [markdown]
# ## Statistics

# %% [markdown]
# ### `stat`

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             stat='count'
            );

# %% [markdown]
# **density** - AREA of histogram sums to one

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             stat='density'
            );

# %% [markdown]
# **probability** - HEIGHT of histogram bars to one

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             stat='probability'
            );

# %% [markdown]
# ### `cumulative`

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             stat='probability', fill=False, element='step',
             cumulative=True
            );

# %% [markdown]
# ## Categorical Variables

# %% [markdown]
# ### `hue`

# %%
sns.histplot(x='flipper_length_mm', data=penguins, hue='species');

# %% [markdown]
# ### `element`

# %%
sns.histplot(x='flipper_length_mm', data=penguins, 
             hue='species',
             element='step'
            );

# %%
sns.histplot(x='flipper_length_mm', data=penguins, 
             hue='species',
             element='poly'
            );

# %% [markdown]
# ### `multiple`

# %%
sns.histplot(x='flipper_length_mm', data=penguins, 
             hue='species', 
             multiple='stack'
            );

# %%
sns.histplot(x='flipper_length_mm', data=penguins, 
             hue='species', 
             multiple='fill'
            );

# %% [markdown]
# **BONUS Example**: `multiple="dodge"`

# %%
sns.histplot(x='species', data=penguins, 
             hue='island', 
             multiple='dodge',
             shrink=0.8
            );

# %% [markdown]
# ## Bivariate Histplot

# %%
sns.set_style('white')

# %%
sns.histplot(x='flipper_length_mm', y='bill_depth_mm', data=penguins);

# %% [markdown]
# ### `cbar`

# %%
sns.histplot(x='flipper_length_mm', y='bill_depth_mm', data=penguins,
             cbar=True
            );

sns.scatterplot(x)

# %% [markdown]
# ### `hue`

# %%
sns.histplot(x='flipper_length_mm', y='bill_depth_mm', data=penguins, hue = 'species');

# %% [markdown]
# ### Discrete color map

# %%
sns.histplot(x='flipper_length_mm', y='species', data=penguins,
             hue='species'
            );

# %% [markdown]
# ## Styling

# %% [markdown]
# ### `shrink`

# %%
sns.histplot(x='species',  hue='sex', multiple='dodge', data=penguins,
             shrink=0.8
            );

# %% [markdown]
# ### `color`, `palette`

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
             color='indigo'
            );

# %%
sns.histplot(x='species',  hue='sex', multiple='dodge', data=penguins,
             shrink=0.8, palette='bone'
            );

# %% [markdown]
# ### `fill`

# %%
sns.histplot(x='flipper_length_mm', data=penguins,
            fill=False
            );

# %%
plt.figure(figsize = (8,5))
plt.rc('axes', labelsize = 14)

# here I am trying to solve the issue in udacity lectures Lesson 5 concept 6 v2  Multivariate visualization adaptation 
# I am trying to find a solution using seaborn for hist2d plot based on the mean of a third continuous variable. 

sns.histplot(x='flipper_length_mm', y='bill_depth_mm', data=penguins, weights = 'body_mass_g', bins = 20, cbar = True,
            cbar_kws={'label': 'body mass (g)'} );

# %% [markdown]
# ### Other `kwargs`
#
# Other keyword arguments can also be used, but allowed keywords depend on the type of histplot you are making:
#
# - Univariate, element="bars": [matplotlib.axes.Axes.bar()](https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.bar.html#matplotlib.axes.Axes.bar)
#
# - Univariate, other element, fill=True: [matplotlib.axes.Axes.fill_between()](https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.fill_between.html#matplotlib.axes.Axes.fill_between)
#
# - Univariate, other element, fill=False: [matplotlib.axes.Axes.plot()](https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.plot.html#matplotlib.axes.Axes.plot)
#
# - Bivariate: [matplotlib.axes.Axes.pcolormesh()](https://matplotlib.org/api/_as_gen/matplotlib.axes.Axes.pcolormesh.html#matplotlib.axes.Axes.pcolormesh)
