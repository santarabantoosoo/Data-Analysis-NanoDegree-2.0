# %% [markdown]
# # Seaborn: scatterplot

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
diamonds = sns.load_dataset('diamonds')

diamonds.shape
# Out:
# (53940, 10)

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
diamonds.cut.unique()
# Out:
# ['Ideal', 'Premium', 'Good', 'Very Good', 'Fair']
# Categories (5, object): ['Ideal', 'Premium', 'Very Good', 'Good', 'Fair']

# %%
diamonds = diamonds[
            diamonds.cut.isin(['Premium', 'Good']) & 
            diamonds.color.isin(['D', 'F', 'J'])
            ].sample(n=100, random_state=22)

diamonds.cut.cat.remove_unused_categories(inplace = True)
diamonds.color.cat.remove_unused_categories(inplace = True)

diamonds.shape
# Out:
# /home/hamza/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/categorical.py:2631: FutureWarning: The `inplace` parameter in pandas.Categorical.remove_unused_categories is deprecated and will be removed in a future version.
#   res = method(*args, **kwargs)
# (100, 10)

# %%
diamonds.cut
# Out:
# 21628    Premium
# 7302     Premium
# 50019    Premium
# 26898    Premium
# 2794        Good
#           ...
# 19116    Premium
# 4517        Good
# 39943       Good
# 35535    Premium
# 46240    Premium
# Name: cut, Length: 100, dtype: category
# Categories (2, object): ['Premium', 'Good']

# %%
diamonds.cut.value_counts()
# Out:
# Premium    69
# Good       31
# Name: cut, dtype: int64

# %%
diamonds.color
# Out:
# 21628    D
# 7302     D
# 50019    F
# 26898    D
# 2794     F
#         ..
# 19116    F
# 4517     D
# 39943    F
# 35535    F
# 46240    F
# Name: color, Length: 100, dtype: category
# Categories (3, object): ['D', 'F', 'J']

# %%
diamonds.color.value_counts()
# Out:
# F    51
# D    33
# J    16
# Name: color, dtype: int64

# %% [markdown]
# ## Intro Visuals

# %%
import pandas as pd
import numpy as np

# %%
sns.set_style('white')
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)

# %%
blue, orange, green, red = sns.color_palette()[:4]

# %%
pts_x = [1] #, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1] #, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic1.svg')
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts_x = [1, 2] #, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3] #, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic2.svg')
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts_x = [1, 2, 1.5] #, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5] #, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic3.svg')
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5] #, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2] #, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic4.svg')
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5] #, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4] #, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasic5.svg')
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pts_x = [1, 2, 1.5, 4, 3, 2.5, 2.1, 1.5, 3.5, 1, 2.6, 3.4, 1.3, 0.5]
pts_y = [1, 3, 2.5, 3, 3.5, 2, 2.5, 1.8, 4, 1.3, 3.2, 3, 2, 1]

plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=150, color='xkcd:crimson', alpha=0.7, edgecolor='black')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.tight_layout()
plt.savefig('08scatter_buildBasicFull.svg')
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
for x,y in zip(pts_x, pts_y):
    print((x, y))
# Out:
# (1, 1)
# (2, 3)
# (1.5, 2.5)
# (4, 3)
# (3, 3.5)
# (2.5, 2)
# (2.1, 2.5)
# (1.5, 1.8)
# (3.5, 4)
# (1, 1.3)
# (2.6, 3.2)
# (3.4, 3)
# (1.3, 2)
# (0.5, 1)

# %%
cat = [0, 0, 1, 1, 0, 0, 1, 0, 1, 1, 0, 0, 1, 1]

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=200, hue=cat, alpha=0.7, edgecolor='black', palette={0: 'xkcd:crimson', 1: '#3d9f98'})
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byHue.png')
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, s=200, style=cat, alpha=0.7, edgecolor='black', color='xkcd:crimson')
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byStyle.png')
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, size=cat, alpha=0.7, edgecolor='black', color='xkcd:crimson', sizes=[50, 300])
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_bySize.png')
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(5, 5))
sns.scatterplot(pts_x, pts_y, size=cat, hue=cat, style=cat,
                alpha=0.7, edgecolor='black',  
                sizes=[100, 300],
                palette={0: 'xkcd:crimson', 1: '#3d9f98'}
               )
sns.despine()
plt.xlim(0, 4.2)
plt.ylim(0, 4.2)
plt.yticks([0, 1, 2, 3, 4])
plt.xticks([1, 2, 3, 4])
plt.gca().get_legend().remove()
plt.tight_layout()
plt.savefig('08scatter_byAll.png')
# Out:
# C:\Users\santarabantoosoo\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %% [markdown]
# ## Basics

# %%
sns.set_style('darkgrid')  # whitegrid - dark

# %%
# sns.scatterplot(diamonds.carat, diamonds.price);
# plt.figure(figsize=(10, 10))
sns.scatterplot(x = 'carat', y = 'price', data = diamonds);

# %%
sns.scatterplot(x='carat', y='price', data=diamonds);

# %%
sns.scatterplot(x='x', y='y', data=diamonds);

# %% [markdown]
# ## Semantic Variables

# %%
sns.set_style('darkgrid')

# %% [markdown]
# ### hue

# %%
plt.figure(figsize = (8, 8))
sns.scatterplot(x='carat', y='price', size='cut', sizes = [50, 250], hue = 'color', style = 'cut',
                data=diamonds
               );

# %%
diamonds.cut.value_counts()
# Out:
# Premium      69
# Good         31
# Ideal         0
# Very Good     0
# Fair          0
# Name: cut, dtype: int64

# %%
sns.scatterplot(x='carat', y='price', hue='color',
                data=diamonds
                ,palette=['green','#55CCCC', 'gray']
               );   # how to choose colors? what options are available?  will check in slides 
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds,
                palette = ['purple', '#55CCCC'],
                hue_order=['Good', 'Premium']
               );

# %% [markdown]
# #### Continuous Variable

# %%
plt.figure(figsize = (8, 6))
sns.scatterplot(x='carat', y='price', hue='depth', 
                data=diamonds, s = 100);  # how to increase size of dots?

# %% [markdown]
# ### style

# %%
sns.scatterplot(x='carat', y='price', hue='cut',
                data=diamonds, 
                s = 150
               );

# %% [markdown]
# ### size

# %%
sns.scatterplot(x='carat', y='price', size='cut', hue = 'cut', # can we add color to the same variable?
                data=diamonds, sizes = [50, 250]
               );

# %%
sns.scatterplot(x='carat', y='price', size='cut',
                data=diamonds, 
                sizes=[150, 50]
               );

# %%
sns.scatterplot(x='carat', y='price', hue='depth',
                data=diamonds
               );

# %% [markdown]
# ### hue + style + size

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='cut',
                data=diamonds,
                size = 'color',
                sizes = [50, 150, 500],
                s=100
               );

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='color',
                data=diamonds,
                s = 200   # can we use different sizes for different cuts?
               ); #hy do we have all these colors?

# %%
diamonds.color.nunique()  # we need to remove unused levels
# Out:
# 3

# %%
# diamonds.color = diamonds.color.cat.remove_unused_categories()

# %%
sns.scatterplot(x='carat', y='price', 
                hue='cut', 
                style='color',
                size='depth',
                data=diamonds);  # can we use more distinguishing sizes?

# %% [markdown]
# ## Additional Styling

# %% [markdown]
# ### alpha

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds,
                s=100,
                alpha=1
               );

# %% [markdown]
# ### marker styling
#
# Check the [matplotlib scatter](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html) and the [marker style docs](https://matplotlib.org/api/_as_gen/matplotlib.markers.MarkerStyle.html#matplotlib.markers.MarkerStyle) for more styling of the markers themselves

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds, 
                s=200,
                marker='*'
               );

# %%
sns.scatterplot(x='carat', y='price', 
                data=diamonds, 
                s=200, 
                marker='*',
                edgecolor='blue'  # from where did we get this?
               );

# %%
sns.relplot(x='carat', y='price', 
                data=diamonds, 
                s=200, 
                marker='*',
                edgecolor='black', col = 'cut'
               );

# %%
sns.catplot(data = diamonds, x = 'depth', y = 'cut', kind = 'box', row = 'color');

# %%
foo = sns.catplot(data = diamonds, x = 'depth', y = 'cut', kind = 'box', col = 'color');

# %%
type(foo)
# Out:
# seaborn.axisgrid.FacetGrid

# %%
diamonds.head()
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 21628   1.26  Premium     D     VS2   62.5   59.0   9720  6.91  6.85  4.30
# 7302    1.20  Premium     D     SI2   60.2   60.0   4203  6.94  6.81  4.14
# 50019   0.70  Premium     F     SI1   62.1   59.0   2196  5.68  5.72  3.54
# 26898   1.54  Premium     D     VS2   59.3   59.0  16889  7.61  7.54  4.49
# 2794    1.00     Good     F     SI2   59.4   64.0   3259  6.52  6.48  3.86

# %%
sns.catplot(data = diamonds, y = 'price', kind = 'box', col = 'cut');

# %%
sns.catplot(data = diamonds, y = 'price', kind = 'swarm', col = 'cut');

# %%
sns.catplot(data = diamonds, y = 'price', kind = 'strip', col = 'cut');

# %%
sns.scatterplot(data = diamonds,x = 'cut', y = 'price');

# %%
sns.violinplot(data = diamonds,x = 'cut', y = 'price');

# %%
sns.countplot(data = diamonds, x= 'cut');

# %%
sns.barplot(data = diamonds, x = 'price', y = 'cut', estimator = np.median, ci = 99);

# %%
sns.boxplot(data = diamonds,x = 'cut', y = 'price');

# %%
sns.kdeplot(data = diamonds, x = 'price')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.kdeplot(data = diamonds, x = 'price')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Density'>

# %%
sns.boxplot(data = diamonds, x = 'cut', y = 'price');

# %%
sns.violinplot(data = diamonds, x = 'cut', y = 'price');
# Out:
# <AxesSubplot:xlabel='cut', ylabel='price'>

# %%
sns.swarmplot(data = diamonds, x = 'cut', y = 'price');

# %%
sns.stripplot(data = diamonds, x = 'cut', y = 'price');

# %%
sns.barplot(data = diamonds, x= 'cut' , y = 'price', estimator = np.median, ci= None);
